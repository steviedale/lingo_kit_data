# %%
import os
import pandas as pd

# %%
save_dir = 'bigrams'
df = pd.read_csv('gram2.tsv', sep='\t')
len(df), df.columns
# Out:
# (12138,
#  Index(['gram2_key', 'count', 'substr', 'term_1', 'term_2', 'lemma_1',
#         'lemma_2', 'pos_1', 'pos_2', 'translation_en'],
#        dtype='object'))

# %%
df.sort_values('count', inplace=True, ascending=False)
df.head()
# Out:
#                               gram2_key  count     substr term_1 term_2  \
# 0       ('non_non_ADV', 'è_essere_AUX')   1461      non è    non      è
# 1   ('ha_avere_AUX', 'detto_dire_VERB')   1391   ha detto     ha  detto
# 2  ('detto_dire_VERB', 'che_che_SCONJ')   1385  detto che  detto    che
# 3         ('io_io_PRON', 'non_non_ADV')   1345     io non     io    non
# 4          ('il_il_DET', 'suo_suo_DET')   1255     il suo     il    suo
#
#   lemma_1 lemma_2 pos_1  pos_2        translation_en
# 0     non  essere   ADV    AUX                is not
# 1   avere    dire   AUX   VERB              has said
# 2    dire     che  VERB  SCONJ             said that
# 3      io     non  PRON    ADV              I do not
# 4      il     suo   DET    DET  his; her (masculine)

# %%
df['translation_en'].notnull().sum()
# Out:
# np.int64(399)

# %%
df[390:410]
# Out:
#                                      gram2_key  count        substr   term_1  \
# 398       ('ti_ti_PRON', 'piace_piacere_VERB')     84      ti piace       ti
# 397           ('tutta_tutto_DET', 'la_il_DET')     84      tutta la    tutta
# 396               ('più_più_ADV', 'di_di_ADP')     84        più di      più
# 395                  ('a_a_ADP', 'un_uno_DET')     84          a un        a
# 389        ('mai_mai_ADV', 'stato_essere_AUX')     84     mai stato      mai
# 393      ('di_di_ADP', 'parlare_parlare_VERB')     84    di parlare       di
# 392            ('è_essere_AUX', 'qui_qui_ADV')     84         è qui        è
# 391               ('se_se_PRON', 'ne_ne_PRON')     84         se ne       se
# 390     ('chiesto_chiedere_VERB', 'di_di_ADP')     84    chiesto di  chiesto
# 399          ("l'_il_DET", 'acqua_acqua_NOUN')     83       l'acqua       l'
# 400      ('cercato_cercare_VERB', 'di_di_ADP')     83    cercato di  cercato
# 401      ('a_a_ADP', 'lavorare_lavorare_VERB')     83    a lavorare        a
# 402      ('perché_perché_ADV', 'è_essere_AUX')     83      perché è   perché
# 403                 ('a_a_ADP', 'che_che_DET')     83         a che        a
# 404      ('suo_suo_DET', 'lavoro_lavoro_NOUN')     83    suo lavoro      suo
# 405  ('una_uno_DET', 'macchina_macchina_NOUN')     83  una macchina      una
# 414      ('dicono_dire_VERB', 'che_che_SCONJ')     82    dicono che   dicono
# 410            ('di_di_ADP', 'vino_vino_NOUN')     82       di vino       di
# 411            ("l'_il_DET", 'anno_anno_NOUN')     82        l'anno       l'
# 413        ('provato_provare_VERB', 'a_a_ADP')     82           NaN  provato
#
#        term_2   lemma_1   lemma_2 pos_1  pos_2      translation_en
# 398     piace        ti   piacere  PRON   VERB         you like it
# 397        la     tutto        il   DET    DET  all the (feminine)
# 396        di       più        di   ADV    ADP           more than
# 395        un         a       uno   ADP    DET    to a (masculine)
# 389     stato       mai    essere   ADV    AUX           ever been
# 393   parlare        di   parlare   ADP   VERB            to speak
# 392       qui    essere       qui   AUX    ADV             is here
# 391        ne        se        ne  PRON   PRON               of it
# 390        di  chiedere        di  VERB    ADP            asked to
# 399     acqua        il     acqua   DET   NOUN                 NaN
# 400        di   cercare        di  VERB    ADP                 NaN
# 401  lavorare         a  lavorare   ADP   VERB                 NaN
# 402         è    perché    essere   ADV    AUX                 NaN
# 403       che         a       che   ADP    DET                 NaN
# 404    lavoro       suo    lavoro   DET   NOUN                 NaN
# 405  macchina       uno  macchina   DET   NOUN                 NaN
# 414       che      dire       che  VERB  SCONJ                 NaN
# 410      vino        di      vino   ADP   NOUN                 NaN
# 411      anno        il      anno   DET   NOUN                 NaN
# 413         a   provare         a  VERB    ADP                 NaN

# %%
os.makedirs(save_dir, exist_ok=True)

# %%
chunk_size = 100
n_chunks = len(df) // chunk_size
remainder = len(df) % chunk_size
if remainder > 0:
    n_chunks += 1
for chunk_i in range(n_chunks):
    start_i = chunk_i * chunk_size
    end_i = min((chunk_i + 1) * chunk_size, len(df))
    chunk_df = df[start_i:end_i]
    chunk_path = os.path.join(save_dir, f'chunk_{chunk_i:03d}.tsv')
    nan_count = chunk_df['translation_en'].isna().sum()
    if nan_count == 0:
        print('completed chunk', chunk_i)
    elif nan_count > 0 and nan_count < end_i - start_i:
        print('partial chunk', chunk_i, 'with', nan_count, 'missing translations')
    chunk_df.to_csv(chunk_path, sep='\t', index=False)
    # print(f'Saved chunk {chunk_i} to {chunk_path}')
# Out:
# completed chunk 0
# completed chunk 1
# completed chunk 2
# partial chunk 3 with 1 missing translations
