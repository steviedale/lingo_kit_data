# %%
import time
import numpy as np
import json
from tqdm import tqdm
import uuid
import os

import pandas as pd

from stanza_tokenizer import StanzaTokenizer

# %%
tokenizer = StanzaTokenizer()

# %%
# text = "C'è un problema"
# text = "Chiedi a Tom come sta Mary."
# Possiamo aiutarvi in qualche maniera?	Can we assist you in any way?	Sto cercando di aiutarlo.	I am trying to help him.	Sono troppo occupato per aiutarlo.	I'm too busy to help him.
# text = 'Possiamo aiutarvi in qualche maniera?'
# text = "Possiamo aiutarvi subito."
# text = "Diglielo adesso!"
# text = "Voglio dirglielo più tardi."
# text = "Devo portarglielo domani."
# text = "Puoi dargliene ancora?"
# text = "Provo a fargliene avere due."
# text = "Preferisco andarmene presto."
# text = "Alla fine se l’è cavata: sa cavarsela sempre."
# text = "Non me la sento: non me la sento di farlo."
# text = "Posso prendermelo io?"
# text = "Tienitelo pure."
# text = "Me lo comprerò più tardi: comprarmelo ora è difficile."
# text = "Dovresti sbrigartela da solo."
# text = "Bisogna mettercene di più."
# text = "Vorrei tenercene alcuni."
# text = "Prometto di restituirglielo."
# text = "Lasciaglielo lì."
# text = "Non riesco a vedermela con lui."
# text = "Hanno voluto toglierselo di torno."
# text = "Stava godendosela al sole."
# text = "Scendo dall’autobus: il biglietto dell’autobus è qui."
# text = "Andiamo all’università tra poco."
# text = "C’è pane nell’acqua? No è solo farina."
# text = "Mettilo sull’armadio."
# text = "L’amico arriva tardi."
# text = "L’ho visto ieri."
# text = "È un po’ complicato."
# text = "D’accordo partiamo adesso."
# text = "Com’è andata?"
# text = "Quell’amico non c’è più."
text = "Entriamo nell’orto poi andiamo all’aeroporto."
# text = "Quest’anno festeggiamo Sant’Antonio."
# text = "Dov’è il telefono?"

text = text.lower()
text = text.replace("’", "'")
text = text.replace("“", '"').replace("”", '"')
text = text.strip()
print(text)

tokens = tokenizer.tokenize(text)
for token in tokens:
    del token['xpos']
    del token['head']
    del token['deprel']
    del token['feats']
    del token['token_hash']
    del token['group_hash']
    print(token)
