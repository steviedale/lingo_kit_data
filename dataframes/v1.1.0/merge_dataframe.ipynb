# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/stevie/repos/lingo_kit_data/dataframes/v1.1.0/dataframes/preposition/all.csv')

# %%
df.to_csv('/Users/stevie/repos/lingo_kit_data/dataframes/v1.1.0/dataframes/preposition/all.csv', index=False)
# Out:
#    term_italian  is_base base_word_italian translation_english  \
# 0             a     True                 a                  to
# 1            di     True                di                  of
# 2            da     True                da                from
# 3            in     True                in                  in
# 4           con     True               con                with
# 5           col    False               con                with
# 6           coi    False               con                with
# 7         collo    False               con                with
# 8         colla    False               con                with
# 9         cogli    False               con                with
# 10        colle    False               con                with
# 11        coll'    False               con                with
# 12           su     True                su                  on
# 13          per     True               per                 for
# 14          tra     True               tra             between
# 15          fra     True               fra             between
# 16          del    False                di              of the
# 17        dello    False                di              of the
# 18        della    False                di              of the
# 19          dei    False                di              of the
# 20        degli    False                di              of the
# 21        delle    False                di              of the
# 22           al    False                 a              to the
# 23         allo    False                 a              to the
# 24         alla    False                 a              to the
# 25           ai    False                 a              to the
# 26         agli    False                 a              to the
# 27         alle    False                 a              to the
# 28          dal    False                da            from the
# 29        dallo    False                da            from the
# 30        dalla    False                da            from the
# 31          dai    False                da            from the
# 32        dagli    False                da            from the
# 33        dalle    False                da            from the
# 34          nel    False                in              in the
# 35        nello    False                in              in the
# 36        nella    False                in              in the
# 37          nei    False                in              in the
# 38        negli    False                in              in the
# 39        nelle    False                in              in the
# 40          sul    False                su              on the
# 41        sullo    False                su              on the
# 42        sulla    False                su              on the
# 43          sui    False                su              on the
# 44        sugli    False                su              on the
# 45        sulle    False                su              on the
#
#             topics preposition_type  \
# 0      core,travel           simple
# 1   core,ownership           simple
# 2      core,travel           simple
# 3    core,location           simple
# 4      core,people           simple
# 5      core,people      articulated
# 6      core,people      articulated
# 7     core,objects      articulated
# 8     core,objects      articulated
# 9      core,people      articulated
# 10     core,places      articulated
# 11     core,people      articulated
# 12   core,location           simple
# 13    core,purpose           simple
# 14   core,location           simple
# 15   core,location           simple
# 16  core,ownership      articulated
# 17  core,ownership      articulated
# 18  core,ownership      articulated
# 19  core,ownership      articulated
# 20  core,ownership      articulated
# 21  core,ownership      articulated
# 22     core,travel      articulated
# 23     core,travel      articulated
# 24     core,travel      articulated
# 25     core,travel      articulated
# 26     core,travel      articulated
# 27     core,travel      articulated
# 28     core,travel      articulated
# 29     core,travel      articulated
# 30     core,travel      articulated
# 31     core,travel      articulated
# 32     core,travel      articulated
# 33     core,travel      articulated
# 34   core,location      articulated
# 35   core,location      articulated
# 36   core,location      articulated
# 37   core,location      articulated
# 38   core,location      articulated
# 39   core,location      articulated
# 40   core,location      articulated
# 41   core,location      articulated
# 42   core,location      articulated
# 43   core,location      articulated
# 44   core,location      articulated
# 45   core,location      articulated
#
#                                                 notes  \
# 0             Used for direction and indirect objects
# 1                      Indicates possession or origin
# 2                            Used for origin or agent
# 3                           Used for places and means
# 4                             Indicates accompaniment
# 5   Used before masculine singular nouns starting ...
# 6                  Used before masculine plural nouns
# 7   Used before masculine singular nouns starting ...
# 8   Used before feminine singular nouns starting w...
# 9   Used before masculine plural nouns starting wi...
# 10                  Used before feminine plural nouns
# 11                          Elided form before vowels
# 12                        Indicates position or topic
# 13                      Indicates purpose or duration
# 14                         Interchangeable with "fra"
# 15                   Often interchangeable with "tra"
# 16                         Combination of "di" + "il"
# 17                         Combination of "di" + "lo"
# 18                         Combination of "di" + "la"
# 19                          Combination of "di" + "i"
# 20                        Combination of "di" + "gli"
# 21                         Combination of "di" + "le"
# 22                          Combination of "a" + "il"
# 23                          Combination of "a" + "lo"
# 24                          Combination of "a" + "la"
# 25                           Combination of "a" + "i"
# 26                         Combination of "a" + "gli"
# 27                          Combination of "a" + "le"
# 28                         Combination of "da" + "il"
# 29                         Combination of "da" + "lo"
# 30                         Combination of "da" + "la"
# 31                          Combination of "da" + "i"
# 32                        Combination of "da" + "gli"
# 33                         Combination of "da" + "le"
# 34                         Combination of "in" + "il"
# 35                         Combination of "in" + "lo"
# 36                         Combination of "in" + "la"
# 37                          Combination of "in" + "i"
# 38                        Combination of "in" + "gli"
# 39                         Combination of "in" + "le"
# 40                         Combination of "su" + "il"
# 41                         Combination of "su" + "lo"
# 42                         Combination of "su" + "la"
# 43                          Combination of "su" + "i"
# 44                        Combination of "su" + "gli"
# 45                         Combination of "su" + "le"
#
#            example_sentence_italian          example_sentence_english
# 0                       Vado a Roma                      I go to Rome
# 1                 Il libro di Maria                      Maria's book
# 2                   Vengo da Milano                 I come from Milan
# 3                   Abito in Italia                   I live in Italy
# 4                Esco con gli amici             I go out with friends
# 5               Esco col mio amico.     I'm going out with my friend.
# 6                Parlo coi ragazzi.        I'm talking with the boys.
# 7        Ho parlato collo studente.         I spoke with the student.
# 8               Scrivo colla penna.             I write with the pen.
# 9                 Esco cogli amici.   I'm going out with the friends.
# 10             Parlo colle ragazze.       I'm talking with the girls.
# 11                 Esco coll'amico.    I'm going out with the friend.
# 12            Il libro è sul tavolo          The book is on the table
# 13                  Questo è per te                   This is for you
# 14         La casa è tra due alberi    The house is between two trees
# 15        Ci vediamo fra due giorni  We'll see each other in two days
# 16              Il colore del cielo              The color of the sky
# 17        Il profumo dello zucchero            The scent of the sugar
# 18            Il suono della musica            The sound of the music
# 19         I giocattoli dei bambini          The toys of the children
# 20       Le opinioni degli studenti      The opinions of the students
# 21            Le case delle ragazze           The houses of the girls
# 22                  Vado al mercato                I go to the market
# 23             Scrivo allo studente            I write to the student
# 24               Parlo alla maestra            I speak to the teacher
# 25              Telefono ai ragazzi                   I call the boys
# 26                 Parlo agli amici             I talk to the friends
# 27              Scrivo alle ragazze              I write to the girls
# 28                 Vengo dal medico            I come from the doctor
# 29                Esco dallo stadio           I exit from the stadium
# 30             Parto dalla stazione          I leave from the station
# 31               Arrivo dai parenti       I arrive from the relatives
# 32              Ritorno dagli amici         I return from the friends
# 33                Esco dalle scuole           I exit from the schools
# 34                Sono nel giardino                I am in the garden
# 35               Entro nello studio             I enter in the studio
# 36                Abito nella città                I live in the city
# 37       I giochi sono nei cassetti       The toys are in the drawers
# 38         Abito negli appartamenti          I live in the apartments
# 39        Ci sono libri nelle borse       There are books in the bags
# 40            Il gatto è sul divano            The cat is on the sofa
# 41        Il libro è sullo scaffale          The book is on the shelf
# 42           La penna è sulla sedia           The pen is on the chair
# 43         Ci sono fiori sui tavoli   There are flowers on the tables
# 44  I bicchieri sono sugli scaffali    The glasses are on the shelves
# 45       Le chiavi sono sulle sedie        The keys are on the chairs
