# %%
import os
import pandas as pd

# %%
text = """
Gli abitanti di Little Hangleton la chiamavano ancora Casa Riddle, anche se erano passati tanti anni da quando i Riddle ci abitavano. 
Si trovava sulla collina che dominava il villaggio: alcune delle finestre erano inchiodate, al tetto mancavano delle tegole e 
l'edera cresceva incolta sulla facciata. Un tempo Casa Riddle era stata una dimora elegante, certo l'edificio più vasto e grandioso 
nel raggio di chilometri, ma ora era umida, desolata e disabitata. Gli hangletoniani convenivano tutti che la vecchia casa era 
sinistra. Mezzo secolo prima, qualcosa di strano e terribile era successo là dentro, qualcosa di cui gli abitanti più anziani del 
villaggio amavano ancora discutere quando erano a corto di pettegolezzi. La storia era stata ripetuta così tante volte, e vi erano 
stati aggiunti così tanti fronzoli che nessuno era più certo di quale fosse la verità. Ogni versione del racconto, comunque, 
cominciava allo stesso modo: cinquant'anni prima, all'alba di una bella giornata d'estate, quando Casa Riddle era ancora ben tenuta e 
imponente, una cameriera era entrata in salotto e aveva trovato morti tutti e tre i Riddle. La cameriera era corsa urlando giù per la 
collina fino al villaggio e aveva radunato tutte le persone che poteva. Sono là stesi con gli occhi spalancati! Freddi come il 
ghiaccio! Ancora vestiti per la cena! Fu chiamata la polizia e tutta quanta Little Hangleton si crogiolò in una curiosità atterrita e 
in una malcelata eccitazione. Nessuno si sforzò di fingersi addolorato per i Riddle, che erano stati assolutamente impopolari. Gli 
anziani signori Riddle, marito e moglie, erano ricchi, snob e sgarbati, e loro figlio Tom, ormai adulto, era anche peggio. Tutto 
quello che importava agli abitanti era l'identità dell'assassino: chiaramente, tre persone in apparenza sane non morivano di colpo per 
cause naturali nella stessa notte. L'Impiccato, il pub locale, fece affari d'oro quella sera: il villaggio al completo accorse per 
discutere gli omicidi. E la ricompensa per quell'uscita serale arrivò quando la cuoca dei Riddle fece un ingresso teatrale e annunciò 
al pub improvvisamente silenzioso che un uomo chiamato Frank Bryce era stato appena arrestato.
"""

# %%
def get_all_csv_files_rec(dir):
    """Ritorna una lista di tutti i file .csv nella directory e nelle sottodirectory."""
    csv_files = []
    for root, dirs, files in os.walk(dir):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    return csv_files
all_csv_files = get_all_csv_files_rec('dataframes')
all_csv_files
# Out:
# ['dataframes/conjunction/però.csv',
#  'dataframes/conjunction/perché.csv',
#  'dataframes/conjunction/e.csv',
#  'dataframes/conjunction/quasi.csv',
#  'dataframes/conjunction/siccome.csv',
#  'dataframes/conjunction/sia.csv',
#  'dataframes/conjunction/quanto.csv',
#  'dataframes/conjunction/come.csv',
#  'dataframes/conjunction/mentre.csv',
#  'dataframes/conjunction/se.csv',
#  'dataframes/conjunction/né.csv',
#  'dataframes/conjunction/oppure.csv',
#  'dataframes/conjunction/quando.csv',
#  'dataframes/conjunction/che.csv',
#  'dataframes/conjunction/ma.csv',
#  'dataframes/conjunction/o.csv',
#  'dataframes/conjunction/per cui.csv',
#  'dataframes/conjunction/così.csv',
#  'dataframes/noun/sapere.csv',
#  'dataframes/noun/pizza.csv',
#  'dataframes/noun/bagno.csv',
#  'dataframes/noun/albergo.csv',
#  'dataframes/noun/basso.csv',
#  'dataframes/noun/perché.csv',
#  'dataframes/noun/pasta.csv',
#  'dataframes/noun/volere.csv',
#  'dataframes/noun/camera.csv',
#  'dataframes/noun/bar.csv',
#  'dataframes/noun/tavolo.csv',
#  'dataframes/noun/autobus.csv',
#  'dataframes/noun/dio.csv',
#  'dataframes/noun/dovere.csv',
#  'dataframes/noun/potere.csv',
#  'dataframes/noun/primo.csv',
#  'dataframes/noun/piccolo.csv',
#  'dataframes/noun/ristorante.csv',
#  'dataframes/noun/biglietto.csv',
#  'dataframes/noun/sedia.csv',
#  'dataframes/noun/sì.csv',
#  'dataframes/noun/aeroporto.csv',
#  'dataframes/noun/male.csv',
#  'dataframes/noun/treno.csv',
#  'dataframes/noun/avere.csv',
#  'dataframes/noun/uscita.csv',
#  'dataframes/noun/negozio.csv',
#  'dataframes/noun/pane.csv',
#  'dataframes/noun/essere.csv',
#  'dataframes/noun/dio_1.csv',
#  'dataframes/noun/caffè.csv',
#  'dataframes/noun/peggio.csv',
#  'dataframes/noun/strada.csv',
#  'dataframes/noun/bene.csv',
#  'dataframes/noun/macchina.csv',
#  'dataframes/noun/ancora.csv',
#  'dataframes/noun/vecchio.csv',
#  'dataframes/noun/acqua.csv',
#  'dataframes/noun/vino.csv',
#  'dataframes/noun/no.csv',
#  'dataframes/verb/sapere.csv',
#  'dataframes/verb/vedere.csv',
#  'dataframes/verb/dare.csv',
#  'dataframes/verb/trovare.csv',
#  'dataframes/verb/fare.csv',
#  'dataframes/verb/volere.csv',
#  'dataframes/verb/essere_1.csv',
#  'dataframes/verb/dovere.csv',
#  'dataframes/verb/subire_1.csv',
#  'dataframes/verb/potere.csv',
#  'dataframes/verb/mettere.csv',
#  'dataframes/verb/ancorare.csv',
#  'dataframes/verb/subire.csv',
#  'dataframes/verb/avere.csv',
#  'dataframes/verb/uscire_1.csv',
#  'dataframes/verb/essere.csv',
#  'dataframes/verb/conoscere.csv',
#  'dataframes/verb/mangiare.csv',
#  'dataframes/verb/venire.csv',
#  'dataframes/verb/bagnare.csv',
#  'dataframes/verb/andare.csv',
#  'dataframes/verb/prendere.csv',
#  'dataframes/verb/uscire.csv',
#  'dataframes/verb/dire.csv',
#  'dataframes/verb/pensare.csv',
#  'dataframes/verb/parlare.csv',
#  'dataframes/adjective/grande.csv',
#  'dataframes/adjective/corto.csv',
#  'dataframes/adjective/spesso.csv',
#  'dataframes/adjective/nuovo.csv',
#  'dataframes/adjective/basso.csv',
#  'dataframes/adjective/bello.csv',
#  'dataframes/adjective/primo.csv',
#  'dataframes/adjective/piccolo.csv',
#  'dataframes/adjective/altro.csv',
#  'dataframes/adjective/ultimo.csv',
#  'dataframes/adjective/lungo.csv',
#  'dataframes/adjective/alto.csv',
#  'dataframes/adjective/buono.csv',
#  'dataframes/adjective/vecchio.csv',
#  'dataframes/pronoun/suo.csv',
#  'dataframes/pronoun/li.csv',
#  'dataframes/pronoun/tu_1.csv',
#  'dataframes/pronoun/lui.csv',
#  'dataframes/pronoun/quello.csv',
#  'dataframes/pronoun/nessuno.csv',
#  'dataframes/pronoun/chi.csv',
#  'dataframes/pronoun/mi.csv',
#  'dataframes/pronoun/tanto.csv',
#  'dataframes/pronoun/lo.csv',
#  'dataframes/pronoun/ti.csv',
#  'dataframes/pronoun/questo.csv',
#  'dataframes/pronoun/loro.csv',
#  'dataframes/pronoun/si.csv',
#  'dataframes/pronoun/tutto.csv',
#  'dataframes/pronoun/dove.csv',
#  'dataframes/pronoun/quanto.csv',
#  'dataframes/pronoun/tuo.csv',
#  'dataframes/pronoun/altrettanto.csv',
#  'dataframes/pronoun/quale.csv',
#  'dataframes/pronoun/gli.csv',
#  'dataframes/pronoun/il quale.csv',
#  'dataframes/pronoun/sé.csv',
#  'dataframes/pronoun/ognuno.csv',
#  'dataframes/pronoun/io.csv',
#  'dataframes/pronoun/qualcuno.csv',
#  'dataframes/pronoun/voi.csv',
#  'dataframes/pronoun/nostro.csv',
#  'dataframes/pronoun/si_1.csv',
#  'dataframes/pronoun/cui.csv',
#  'dataframes/pronoun/altro.csv',
#  'dataframes/pronoun/lei.csv',
#  'dataframes/pronoun/poco.csv',
#  'dataframes/pronoun/alcuno.csv',
#  'dataframes/pronoun/ecco.csv',
#  'dataframes/pronoun/ciascuno.csv',
#  'dataframes/pronoun/mio.csv',
#  'dataframes/pronoun/che.csv',
#  'dataframes/pronoun/me.csv',
#  'dataframes/pronoun/la.csv',
#  'dataframes/pronoun/le.csv',
#  'dataframes/pronoun/tu.csv',
#  'dataframes/pronoun/noi.csv',
#  'dataframes/pronoun/uno.csv',
#  'dataframes/pronoun/ci.csv',
#  'dataframes/pronoun/molto.csv',
#  'dataframes/pronoun/vi.csv',
#  'dataframes/pronoun/troppo.csv',
#  'dataframes/pronoun/vostro.csv',
#  'dataframes/article/un.csv',
#  'dataframes/article/del.csv',
#  'dataframes/article/il.csv',
#  'dataframes/adverb/però.csv',
#  'dataframes/adverb/dentro.csv',
#  'dataframes/adverb/subito.csv',
#  'dataframes/adverb/spesso.csv',
#  'dataframes/adverb/perché.csv',
#  'dataframes/adverb/tanto.csv',
#  'dataframes/adverb/quasi.csv',
#  'dataframes/adverb/tutto.csv',
#  'dataframes/adverb/dove.csv',
#  'dataframes/adverb/quanto.csv',
#  'dataframes/adverb/mai.csv',
#  'dataframes/adverb/come.csv',
#  'dataframes/adverb/altrettanto.csv',
#  'dataframes/adverb/poi.csv',
#  'dataframes/adverb/su.csv',
#  'dataframes/adverb/sì.csv',
#  'dataframes/adverb/male.csv',
#  'dataframes/adverb/poco.csv',
#  'dataframes/adverb/peggio.csv',
#  'dataframes/adverb/già.csv',
#  'dataframes/adverb/bene.csv',
#  'dataframes/adverb/sempre.csv',
#  'dataframes/adverb/ecco.csv',
#  'dataframes/adverb/quando.csv',
#  'dataframes/adverb/ancora.csv',
#  'dataframes/adverb/così.csv',
#  'dataframes/adverb/molto.csv',
#  'dataframes/adverb/troppo.csv',
#  'dataframes/adverb/no.csv',
#  'dataframes/determiner/suo.csv',
#  'dataframes/determiner/quello.csv',
#  'dataframes/determiner/nessuno.csv',
#  'dataframes/determiner/tanto.csv',
#  'dataframes/determiner/questo.csv',
#  'dataframes/determiner/loro.csv',
#  'dataframes/determiner/tutto.csv',
#  'dataframes/determiner/quanto.csv',
#  'dataframes/determiner/tuo.csv',
#  'dataframes/determiner/altrettanto.csv',
#  'dataframes/determiner/quale.csv',
#  'dataframes/determiner/nostro.csv',
#  'dataframes/determiner/altro.csv',
#  'dataframes/determiner/poco.csv',
#  'dataframes/determiner/alcuno.csv',
#  'dataframes/determiner/ogni.csv',
#  'dataframes/determiner/ciascuno.csv',
#  'dataframes/determiner/mio.csv',
#  'dataframes/determiner/qualche.csv',
#  'dataframes/determiner/uno.csv',
#  'dataframes/determiner/molto.csv',
#  'dataframes/determiner/troppo.csv',
#  'dataframes/determiner/vostro.csv',
#  'dataframes/preposition/dentro.csv',
#  'dataframes/preposition/a.csv',
#  'dataframes/preposition/di_1.csv',
#  'dataframes/preposition/di_3.csv',
#  'dataframes/preposition/di_2.csv',
#  'dataframes/preposition/di_6.csv',
#  'dataframes/preposition/di_5.csv',
#  'dataframes/preposition/per.csv',
#  'dataframes/preposition/di_4.csv',
#  'dataframes/preposition/da.csv',
#  'dataframes/preposition/fra.csv',
#  'dataframes/preposition/con.csv',
#  'dataframes/preposition/come.csv',
#  'dataframes/preposition/su.csv',
#  'dataframes/preposition/di.csv',
#  'dataframes/preposition/in.csv',
#  'dataframes/preposition/lungo.csv',
#  'dataframes/preposition/tra.csv',
#  'dataframes/preposition/su/on.csv']

# %%
all_df = pd.DataFrame()
for path in all_csv_files:
    assert(os.path.exists(path))
    # print(path)
    df = pd.read_csv(path)
    all_df = pd.concat([all_df, df], ignore_index=True)
len(all_df), all_df.columns
# Out:
# (1843,
#  Index(['term_italian', 'is_base', 'base_lemma_italian', 'base_lemma_english',
#         'part_of_speech', 'translation_english', 'topics', 'subtype',
#         'person_number', 'gender', 'plurality', 'mood', 'tense',
#         'is_comparative', 'is_superlative', 'is_compound', 'article_type',
#         'article_italian', 'added_particle_italian', 'preposition', 'notes',
#         'example_sentence_italian', 'example_sentence_english'],
#        dtype='object'))

# %%
harry_potter_words = set(text.lower().replace('\n', ' ').replace('.', ' ').replace(',', ' ').replace('!', ' ').replace('?', ' ').split(' '))
# ignore empty strings
harry_potter_words.discard('')
# ignore numbers
harry_potter_words = {w for w in harry_potter_words if not w.isdigit()}
harry_potter_words
# Out:
# {'a',
#  'abitanti',
#  'abitavano',
#  'accorse',
#  'addolorato',
#  'adulto',
#  'affari',
#  'aggiunti',
#  'agli',
#  'al',
#  'alcune',
#  "all'alba",
#  'allo',
#  'amavano',
#  'anche',
#  'ancora',
#  'anni',
#  'annunciò',
#  'anziani',
#  'apparenza',
#  'appena',
#  'arrestato',
#  'arrivò',
#  'assolutamente',
#  'atterrita',
#  'aveva',
#  'bella',
#  'ben',
#  'bryce',
#  'cameriera',
#  'casa',
#  'cause',
#  'cena',
#  'certo',
#  'che',
#  'chiamata',
#  'chiamato',
#  'chiamavano',
#  'chiaramente',
#  'chilometri',
#  'ci',
#  "cinquant'anni",
#  'collina',
#  'colpo',
#  'come',
#  'cominciava',
#  'completo',
#  'comunque',
#  'con',
#  'convenivano',
#  'corsa',
#  'corto',
#  'così',
#  'cresceva',
#  'crogiolò',
#  'cui',
#  'cuoca',
#  'curiosità',
#  "d'estate",
#  "d'oro",
#  'da',
#  'dei',
#  'del',
#  "dell'assassino:",
#  'delle',
#  'dentro',
#  'desolata',
#  'di',
#  'dimora',
#  'disabitata',
#  'discutere',
#  'dominava',
#  'e',
#  'eccitazione',
#  'elegante',
#  'entrata',
#  'era',
#  'erano',
#  'facciata',
#  'fece',
#  'figlio',
#  'finestre',
#  'fingersi',
#  'fino',
#  'fosse',
#  'frank',
#  'freddi',
#  'fronzoli',
#  'fu',
#  'ghiaccio',
#  'giornata',
#  'giù',
#  'gli',
#  'grandioso',
#  'hangleton',
#  'hangletoniani',
#  'i',
#  'il',
#  'imponente',
#  'impopolari',
#  'importava',
#  'improvvisamente',
#  'in',
#  'inchiodate',
#  'incolta',
#  'ingresso',
#  "l'edera",
#  "l'edificio",
#  "l'identità",
#  "l'impiccato",
#  'la',
#  'le',
#  'little',
#  'locale',
#  'loro',
#  'là',
#  'ma',
#  'malcelata',
#  'mancavano',
#  'marito',
#  'mezzo',
#  'modo:',
#  'moglie',
#  'morivano',
#  'morti',
#  'naturali',
#  'nel',
#  'nella',
#  'nessuno',
#  'non',
#  'notte',
#  'occhi',
#  'ogni',
#  'omicidi',
#  'ora',
#  'ormai',
#  'passati',
#  'peggio',
#  'per',
#  'persone',
#  'pettegolezzi',
#  'più',
#  'polizia',
#  'poteva',
#  'prima',
#  'pub',
#  'qualcosa',
#  'quale',
#  'quando',
#  'quanta',
#  "quell'uscita",
#  'quella',
#  'quello',
#  'racconto',
#  'radunato',
#  'raggio',
#  'ricchi',
#  'ricompensa',
#  'riddle',
#  'ripetuta',
#  'salotto',
#  'sane',
#  'se',
#  'secolo',
#  'sera:',
#  'serale',
#  'sforzò',
#  'sgarbati',
#  'si',
#  'signori',
#  'silenzioso',
#  'sinistra',
#  'snob',
#  'sono',
#  'spalancati',
#  'stata',
#  'stati',
#  'stato',
#  'stesi',
#  'stessa',
#  'stesso',
#  'storia',
#  'strano',
#  'successo',
#  'sulla',
#  'tante',
#  'tanti',
#  'teatrale',
#  'tegole',
#  'tempo',
#  'tenuta',
#  'terribile',
#  'tetto',
#  'tom',
#  'tre',
#  'trovato',
#  'trovava',
#  'tutta',
#  'tutte',
#  'tutti',
#  'tutto',
#  'umida',
#  'un',
#  'una',
#  'uomo',
#  'urlando',
#  'vasto',
#  'vecchia',
#  'verità',
#  'versione',
#  'vestiti',
#  'vi',
#  'villaggio',
#  'villaggio:',
#  'volte'}

# %%
# term = 'ancora'
term = 'lei'
cols = ['term_italian', 'part_of_speech', 'translation_english', 'base_lemma_italian', 'base_lemma_english']
all_df[all_df['term_italian'] == term][cols]
# Out:
#     term_italian part_of_speech translation_english base_lemma_italian  \
# 895          lei        pronoun                 she                lei
# 897          lei        pronoun                 her                lei
#
#     base_lemma_english
# 895   she/you (formal)
# 897   she/you (formal)

# %%
term = 'ancora'
# term = 'lei'
cols = ['term_italian', 'translation_english', 'part_of_speech', 'base_lemma_italian', 'base_lemma_english']
all_df[all_df['term_italian'].str.lower().str.contains(term)][cols]
# Out:
#          term_italian                                translation_english  \
# 404            ancora                                             anchor
# 405         un'ancora                                          an anchor
# 406          l'ancora                                         the anchor
# 410       dell'ancora                                      of the anchor
# 411        all'ancora                                          at anchor
# 413       dall'ancora                                    from the anchor
# 415       nell'ancora                                      in the anchor
# 417       sull'ancora                                      on the anchor
# 419      con l'ancora                                    with the anchor
# 546          ancorare                                          to anchor
# 547         ancorando                                          anchoring
# 548          ancorato                                           anchored
# 549          ancorata                                           anchored
# 550          ancorati                                           anchored
# 551          ancorate                                           anchored
# 554            ancora         he anchors/she anchors/you (formal) anchor
# 556          ancorate                                you (plural) anchor
# 557          ancorano                                        they anchor
# 558          ancoravo                                    I was anchoring
# 559          ancoravi                                 you were anchoring
# 560          ancorava  he was anchoring/she was anchoring/you (formal...
# 561        ancoravamo                                  we were anchoring
# 562        ancoravate                        you (plural) were anchoring
# 563        ancoravano                                they were anchoring
# 564       ho ancorato                                    I have anchored
# 565      hai ancorato                                  you have anchored
# 566       ha ancorato  he has anchored/she has anchored/you (formal) ...
# 567  abbiamo ancorato                                   we have anchored
# 568    avete ancorato                         you (plural) have anchored
# 569    hanno ancorato                                 they have anchored
# 990            ancora                                    still/again/yet
#
#     part_of_speech base_lemma_italian base_lemma_english
# 404           noun             ancora             anchor
# 405           noun             ancora             anchor
# 406           noun             ancora             anchor
# 410           noun             ancora             anchor
# 411           noun             ancora             anchor
# 413           noun             ancora             anchor
# 415           noun             ancora             anchor
# 417           noun             ancora             anchor
# 419           noun             ancora             anchor
# 546           verb           ancorare          to anchor
# 547           verb           ancorare          to anchor
# 548           verb           ancorare          to anchor
# 549           verb           ancorare          to anchor
# 550           verb           ancorare          to anchor
# 551           verb           ancorare          to anchor
# 554           verb           ancorare          to anchor
# 556           verb           ancorare          to anchor
# 557           verb           ancorare          to anchor
# 558           verb           ancorare          to anchor
# 559           verb           ancorare          to anchor
# 560           verb           ancorare          to anchor
# 561           verb           ancorare          to anchor
# 562           verb           ancorare          to anchor
# 563           verb           ancorare          to anchor
# 564           verb           ancorare          to anchor
# 565           verb           ancorare          to anchor
# 566           verb           ancorare          to anchor
# 567           verb           ancorare          to anchor
# 568           verb           ancorare          to anchor
# 569           verb           ancorare          to anchor
# 990         adverb             ancora        still/again

# %%
our_words = set(all_df['term_italian'].tolist())
len(our_words)
# Out:
# 1060

# %%
intersection = harry_potter_words.intersection(our_words)
missing = harry_potter_words.difference(our_words)
print(f"INTERSECTION: {len(intersection)}: {sorted(intersection)}")
print(f"MISSING: {len(missing)}: {sorted(missing)}")
# Out:
# INTERSECTION: 64: ['a', 'agli', 'al', 'alcune', 'allo', 'ancora', 'aveva', 'bella', 'che', 'ci', 'come', 'con', 'corto', 'così', 'cui', 'da', 'dei', 'del', 'delle', 'dentro', 'di', 'e', 'era', 'erano', 'gli', 'i', 'il', 'in', 'la', 'le', 'loro', 'ma', 'nel', 'nella', 'nessuno', 'ogni', 'peggio', 'per', 'poteva', 'prima', 'quale', 'quando', 'quanta', 'quella', 'quello', 'se', 'si', 'sono', 'stata', 'stati', 'stato', 'sulla', 'tante', 'tanti', 'trovato', 'trovava', 'tutta', 'tutte', 'tutti', 'tutto', 'un', 'una', 'vecchia', 'vi']
# MISSING: 152: ['abitanti', 'abitavano', 'accorse', 'addolorato', 'adulto', 'affari', 'aggiunti', "all'alba", 'amavano', 'anche', 'anni', 'annunciò', 'anziani', 'apparenza', 'appena', 'arrestato', 'arrivò', 'assolutamente', 'atterrita', 'ben', 'bryce', 'cameriera', 'capitolo', 'casa', 'cause', 'cena', 'certo', 'chiamata', 'chiamato', 'chiamavano', 'chiaramente', 'chilometri', "cinquant'anni", 'collina', 'colpo', 'cominciava', 'completo', 'comunque', 'convenivano', 'corsa', 'cresceva', 'crogiolò', 'cuoca', 'curiosità', "d'estate", "d'oro", "dell'assassino:", 'desolata', 'dimora', 'disabitata', 'discutere', 'dominava', 'eccitazione', 'elegante', 'entrata', 'facciata', 'fece', 'figlio', 'finestre', 'fingersi', 'fino', 'fosse', 'frank', 'freddi', 'fronzoli', 'fu', 'ghiaccio', 'giornata', 'giù', 'grandioso', 'hangleton', 'hangletoniani', 'imponente', 'impopolari', 'importava', 'improvvisamente', 'inchiodate', 'incolta', 'ingresso', "l'edera", "l'edificio", "l'identità", "l'impiccato", 'little', 'locale', 'là', 'malcelata', 'mancavano', 'marito', 'mezzo', 'modo:', 'moglie', 'morivano', 'morti', 'naturali', 'non', 'notte', 'occhi', 'omicidi', 'ora', 'ormai', 'passati', 'persone', 'pettegolezzi', 'più', 'polizia', 'pub', 'qualcosa', "quell'uscita", 'racconto', 'radunato', 'raggio', 'ricchi', 'ricompensa', 'riddle', 'ripetuta', 'salotto', 'sane', 'secolo', 'sera:', 'serale', 'sforzò', 'sgarbati', 'signori', 'silenzioso', 'sinistra', 'snob', 'spalancati', 'stesi', 'stessa', 'stesso', 'storia', 'strano', 'successo', 'teatrale', 'tegole', 'tempo', 'tenuta', 'terribile', 'tetto', 'tom', 'tre', 'umida', 'uomo', 'urlando', 'vasto', 'verità', 'versione', 'vestiti', 'villaggio', 'villaggio:', 'volte']

# %%
important_missing = ['come', 'cui', "d'estate", 'dentro', 'di', 'quando']

# %%
for word in important_missing:
    n = (all_df['term_italian'] == word).sum()
    if n == 0:
        print(f"Missing important word: {word}")
# Out:
# Missing important word: d'estate

# %%
second_page_words = [
    'il', 'lo', 'la', 'i', 'gli', 'le',
    'un', 'una', 'uno',
    'dei', 'degli', 'delle',
    'al', 'alla', 'allo',
    'del', 'della', 'dello', 'dei',
    'coi',
    'per', 'di', 'a', 'da', 'in', 'su', 'sui', 'con', 'tra',
    'e', 'o', 'ma', 'che', 'se', 'mentre', 'quando', 'poi', 'proprio', 'né',
    'eh', 'ecco', 'sì', 'no',
    'mi', 'ti', 'si', 'ci', 'vi',
    'lo', 'la', 'li', 'le',
    'gli', 'le', 'loro',
    'me', 'te', 'sé', 'noi', 'voi',
    'questo', 'questa', 'questi', 'queste',
    'quello', 'quella', 'quelli', 'quelle',
    'quasi',
    'nessuno', 'qualcuno', 'altro',
    'tutto',
    'chi', 'cui', 'dove', 'come', 'perché', 'quanto'
]

# %%
for word in second_page_words:
    n = (all_df['term_italian'] == word).sum()
    if n == 0:
        print(f"Missing important word: {word}")
# Out:
# Missing important word: proprio
# Missing important word: eh
