# %%
import os
from tqdm import tqdm
import pandas as pd
import sys
sys.path.append('/Users/stevie/repos/lingo_kit_data/')
from utils.chatgpt.generate_with_chatgpt import generate_csv
from csv_helper import get_all_terms_df

# %%
path = '/Users/stevie/repos/lingo_kit_data/dataframes/old_dataframes/spotify_lessons.csv'
assert(os.path.exists(path))
df = pd.read_csv(path)
len(df), df.columns
# Out:
# (836,
#  Index(['english_term', 'italian_term', 'part_of_speech', 'topics',
#         'english_base_term', 'italian_base_term'],
#        dtype='object'))

# %%
punctuations = '''!()-[]{};:"\,<>./?@#$%^&*_~'''
word_set = set()
for i, row in tqdm(df.iterrows(), total=len(df)):
    words = row['italian_term'].lower().split(' ')
    for word in words:
        for p in punctuations:
            word = word.replace(p, '')
        if word != '':
            word_set.add(word)
len(word_set)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\,'
# <>:1: SyntaxWarning: invalid escape sequence '\,'
# /var/folders/qs/n3mb_ckd47n6s9c65b_06xrw0000gn/T/ipykernel_29572/3164984852.py:1: SyntaxWarning: invalid escape sequence '\,'
#   punctuations = '''!()-[]{};:"\,<>./?@#$%^&*_~'''
# 100%|██████████| 836/836 [00:00<00:00, 68301.03it/s]
# 613

# %%
italian_words = list(sorted(word_set))

# %%
new_list = []
all_df = get_all_terms_df()
for term_it in tqdm(italian_words):
    if term_it.lower() in all_df['term_italian'].str.lower().values:
        print(f"Skipping term '{term_it}' as it already exists in the dataset.")
    else:
        new_list.append(term_it)
len(new_list)
# Out:
# 100%|██████████| 613/613 [00:00<00:00, 3446.67it/s]
# Skipping term 'a' as it already exists in the dataset.
# Skipping term 'abbastanza' as it already exists in the dataset.
# Skipping term 'abiti' as it already exists in the dataset.
# Skipping term 'accanto' as it already exists in the dataset.
# Skipping term 'acqua' as it already exists in the dataset.
# Skipping term 'adesso' as it already exists in the dataset.
# Skipping term 'aereo' as it already exists in the dataset.
# Skipping term 'aeroporto' as it already exists in the dataset.
# Skipping term 'albergo' as it already exists in the dataset.
# Skipping term 'alcuni' as it already exists in the dataset.
# Skipping term 'all'aeroporto' as it already exists in the dataset.
# Skipping term 'all'angolo' as it already exists in the dataset.
# Skipping term 'alla' as it already exists in the dataset.
# Skipping term 'alle' as it already exists in the dataset.
# Skipping term 'allora' as it already exists in the dataset.
# Skipping term 'alta' as it already exists in the dataset.
# Skipping term 'alto' as it already exists in the dataset.
# Skipping term 'altro' as it already exists in the dataset.
# Skipping term 'americana' as it already exists in the dataset.
# Skipping term 'americano' as it already exists in the dataset.
# Skipping term 'amica' as it already exists in the dataset.
# Skipping term 'amico' as it already exists in the dataset.
# Skipping term 'amo' as it already exists in the dataset.
# Skipping term 'anche' as it already exists in the dataset.
# Skipping term 'ancora' as it already exists in the dataset.
# Skipping term 'andare' as it already exists in the dataset.
# Skipping term 'andata' as it already exists in the dataset.
# Skipping term 'anni' as it already exists in the dataset.
# Skipping term 'anno' as it already exists in the dataset.
# Skipping term 'anticipo' as it already exists in the dataset.
# Skipping term 'antipasto' as it already exists in the dataset.
# Skipping term 'aperta' as it already exists in the dataset.
# Skipping term 'aperto' as it already exists in the dataset.
# Skipping term 'aria' as it already exists in the dataset.
# Skipping term 'armadietto' as it already exists in the dataset.
# Skipping term 'arriva' as it already exists in the dataset.
# Skipping term 'arrivederci' as it already exists in the dataset.
# Skipping term 'assegno' as it already exists in the dataset.
# Skipping term 'attenta' as it already exists in the dataset.
# Skipping term 'attento' as it already exists in the dataset.
# Skipping term 'attenzione' as it already exists in the dataset.
# Skipping term 'attraverso' as it already exists in the dataset.
# Skipping term 'autobus' as it already exists in the dataset.
# Skipping term 'avanti' as it already exists in the dataset.
# Skipping term 'avere' as it already exists in the dataset.
# Skipping term 'avete' as it already exists in the dataset.
# Skipping term 'bagagli' as it already exists in the dataset.
# Skipping term 'bagno' as it already exists in the dataset.
# Skipping term 'bambina' as it already exists in the dataset.
# Skipping term 'bambino' as it already exists in the dataset.
# Skipping term 'banca' as it already exists in the dataset.
# Skipping term 'banco' as it already exists in the dataset.
# Skipping term 'bancomat' as it already exists in the dataset.
# Skipping term 'banconota' as it already exists in the dataset.
# Skipping term 'bar' as it already exists in the dataset.
# Skipping term 'barbiere' as it already exists in the dataset.
# Skipping term 'barca' as it already exists in the dataset.
# Skipping term 'bassa' as it already exists in the dataset.
# Skipping term 'basso' as it already exists in the dataset.
# Skipping term 'bel' as it already exists in the dataset.
# Skipping term 'bella' as it already exists in the dataset.
# Skipping term 'bellezza' as it already exists in the dataset.
# Skipping term 'bello' as it already exists in the dataset.
# Skipping term 'bene' as it already exists in the dataset.
# Skipping term 'benissimo' as it already exists in the dataset.
# Skipping term 'bevanda' as it already exists in the dataset.
# Skipping term 'biglietteria' as it already exists in the dataset.
# Skipping term 'biglietti' as it already exists in the dataset.
# Skipping term 'biglietto' as it already exists in the dataset.
# Skipping term 'binario' as it already exists in the dataset.
# Skipping term 'bisogno' as it already exists in the dataset.
# Skipping term 'blocchetto' as it already exists in the dataset.
# Skipping term 'brava' as it already exists in the dataset.
# Skipping term 'bravo' as it already exists in the dataset.
# Skipping term 'britannica' as it already exists in the dataset.
# Skipping term 'britannico' as it already exists in the dataset.
# Skipping term 'buon' as it already exists in the dataset.
# Skipping term 'buona' as it already exists in the dataset.
# Skipping term 'buonanotte' as it already exists in the dataset.
# Skipping term 'buonasera' as it already exists in the dataset.
# Skipping term 'buongiorno' as it already exists in the dataset.
# Skipping term 'buono' as it already exists in the dataset.
# Skipping term 'c'è' as it already exists in the dataset.
# Skipping term 'caffè' as it already exists in the dataset.
# Skipping term 'calda' as it already exists in the dataset.
# Skipping term 'caldo' as it already exists in the dataset.
# Skipping term 'cambiare' as it already exists in the dataset.
# Skipping term 'cambio' as it already exists in the dataset.
# Skipping term 'camera' as it already exists in the dataset.
# Skipping term 'cameriera' as it already exists in the dataset.
# Skipping term 'cameriere' as it already exists in the dataset.
# Skipping term 'capisce' as it already exists in the dataset.
# Skipping term 'capisco' as it already exists in the dataset.
# Skipping term 'capolinea' as it already exists in the dataset.
# Skipping term 'cara' as it already exists in the dataset.
# Skipping term 'caro' as it already exists in the dataset.
# Skipping term 'carrozza' as it already exists in the dataset.
# Skipping term 'carta' as it already exists in the dataset.
# Skipping term 'cartina' as it already exists in the dataset.
# Skipping term 'casa' as it already exists in the dataset.
# Skipping term 'caso' as it already exists in the dataset.
# Skipping term 'cassa' as it already exists in the dataset.
# Skipping term 'cattiva' as it already exists in the dataset.
# Skipping term 'cattivo' as it already exists in the dataset.
# Skipping term 'causa' as it already exists in the dataset.
# Skipping term 'ce' as it already exists in the dataset.
# Skipping term 'cento' as it already exists in the dataset.
# Skipping term 'centomila' as it already exists in the dataset.
# Skipping term 'cerco' as it already exists in the dataset.
# Skipping term 'certamente' as it already exists in the dataset.
# Skipping term 'certo' as it already exists in the dataset.
# Skipping term 'che' as it already exists in the dataset.
# Skipping term 'chi' as it already exists in the dataset.
# Skipping term 'chiamare' as it already exists in the dataset.
# Skipping term 'chiamo' as it already exists in the dataset.
# Skipping term 'chiaro' as it already exists in the dataset.
# Skipping term 'chiave' as it already exists in the dataset.
# Skipping term 'chilometri' as it already exists in the dataset.
# Skipping term 'chiusa' as it already exists in the dataset.
# Skipping term 'chiuso' as it already exists in the dataset.
# Skipping term 'ci' as it already exists in the dataset.
# Skipping term 'ciao' as it already exists in the dataset.
# Skipping term 'cibo' as it already exists in the dataset.
# Skipping term 'cima' as it already exists in the dataset.
# Skipping term 'cinquanta' as it already exists in the dataset.
# Skipping term 'cinque' as it already exists in the dataset.
# Skipping term 'cinquecento' as it already exists in the dataset.
# Skipping term 'circa' as it already exists in the dataset.
# Skipping term 'città' as it already exists in the dataset.
# Skipping term 'classe' as it already exists in the dataset.
# Skipping term 'coincidenza' as it already exists in the dataset.
# Skipping term 'coincidenze' as it already exists in the dataset.
# Skipping term 'come' as it already exists in the dataset.
# Skipping term 'comprare' as it already exists in the dataset.
# Skipping term 'con' as it already exists in the dataset.
# Skipping term 'condizionata' as it already exists in the dataset.
# Skipping term 'conosco' as it already exists in the dataset.
# Skipping term 'consolato' as it already exists in the dataset.
# Skipping term 'conto' as it already exists in the dataset.
# Skipping term 'contorno' as it already exists in the dataset.
# Skipping term 'contrario' as it already exists in the dataset.
# Skipping term 'contro' as it already exists in the dataset.
# Skipping term 'corso' as it already exists in the dataset.
# Skipping term 'cos'è' as it already exists in the dataset.
# Skipping term 'cosa' as it already exists in the dataset.
# Skipping term 'così' as it already exists in the dataset.
# Skipping term 'da' as it already exists in the dataset.
# Skipping term 'dagli' as it already exists in the dataset.
# Skipping term 'davanti' as it already exists in the dataset.
# Skipping term 'degli' as it already exists in the dataset.
# Skipping term 'dei' as it already exists in the dataset.
# Skipping term 'del' as it already exists in the dataset.
# Skipping term 'dell'autobus' as it already exists in the dataset.
# Skipping term 'della' as it already exists in the dataset.
# Skipping term 'dentro' as it already exists in the dataset.
# Skipping term 'detto' as it already exists in the dataset.
# Skipping term 'devo' as it already exists in the dataset.
# Skipping term 'di' as it already exists in the dataset.
# Skipping term 'dice' as it already exists in the dataset.
# Skipping term 'dietro' as it already exists in the dataset.
# Skipping term 'donna' as it already exists in the dataset.
# Skipping term 'dopo' as it already exists in the dataset.
# Skipping term 'dove' as it already exists in the dataset.
# Skipping term 'dovrei' as it already exists in the dataset.
# Skipping term 'e' as it already exists in the dataset.
# Skipping term 'ecco' as it already exists in the dataset.
# Skipping term 'entro' as it already exists in the dataset.
# Skipping term 'fa' as it already exists in the dataset.
# Skipping term 'fare' as it already exists in the dataset.
# Skipping term 'fine' as it already exists in the dataset.
# Skipping term 'finestra' as it already exists in the dataset.
# Skipping term 'fino' as it already exists in the dataset.
# Skipping term 'fra' as it already exists in the dataset.
# Skipping term 'fredda' as it already exists in the dataset.
# Skipping term 'freddo' as it already exists in the dataset.
# Skipping term 'fumatori' as it already exists in the dataset.
# Skipping term 'ghiaccio' as it already exists in the dataset.
# Skipping term 'già' as it already exists in the dataset.
# Skipping term 'giù' as it already exists in the dataset.
# Skipping term 'gli' as it already exists in the dataset.
# Skipping term 'grande' as it already exists in the dataset.
# Skipping term 'ha' as it already exists in the dataset.
# Skipping term 'hai' as it already exists in the dataset.
# Skipping term 'ho' as it already exists in the dataset.
# Skipping term 'i' as it already exists in the dataset.
# Skipping term 'il' as it already exists in the dataset.
# Skipping term 'in' as it already exists in the dataset.
# Skipping term 'io' as it already exists in the dataset.
# Skipping term 'l'acqua' as it already exists in the dataset.
# Skipping term 'l'aereo' as it already exists in the dataset.
# Skipping term 'l'aeroporto' as it already exists in the dataset.
# Skipping term 'l'angolo' as it already exists in the dataset.
# Skipping term 'l'anno' as it already exists in the dataset.
# Skipping term 'l'autobus' as it already exists in the dataset.
# Skipping term 'l'ora' as it already exists in the dataset.
# Skipping term 'l'uscita' as it already exists in the dataset.
# Skipping term 'la' as it already exists in the dataset.
# Skipping term 'le' as it already exists in the dataset.
# Skipping term 'lei' as it already exists in the dataset.
# Skipping term 'lontana' as it already exists in the dataset.
# Skipping term 'lontano' as it already exists in the dataset.
# Skipping term 'loro' as it already exists in the dataset.
# Skipping term 'lui' as it already exists in the dataset.
# Skipping term 'là' as it already exists in the dataset.
# Skipping term 'ma' as it already exists in the dataset.
# Skipping term 'macchina' as it already exists in the dataset.
# Skipping term 'macchine' as it already exists in the dataset.
# Skipping term 'male' as it already exists in the dataset.
# Skipping term 'mariti' as it already exists in the dataset.
# Skipping term 'marito' as it already exists in the dataset.
# Skipping term 'me' as it already exists in the dataset.
# Skipping term 'mezza' as it already exists in the dataset.
# Skipping term 'mezzo' as it already exists in the dataset.
# Skipping term 'mi' as it already exists in the dataset.
# Skipping term 'mia' as it already exists in the dataset.
# Skipping term 'mie' as it already exists in the dataset.
# Skipping term 'miei' as it already exists in the dataset.
# Skipping term 'minestra' as it already exists in the dataset.
# Skipping term 'mio' as it already exists in the dataset.
# Skipping term 'mogli' as it already exists in the dataset.
# Skipping term 'moglie' as it already exists in the dataset.
# Skipping term 'molta' as it already exists in the dataset.
# Skipping term 'molti' as it already exists in the dataset.
# Skipping term 'molto' as it already exists in the dataset.
# Skipping term 'ne' as it already exists in the dataset.
# Skipping term 'negozio' as it already exists in the dataset.
# Skipping term 'nel' as it already exists in the dataset.
# Skipping term 'no' as it already exists in the dataset.
# Skipping term 'noi' as it already exists in the dataset.
# Skipping term 'non' as it already exists in the dataset.
# Skipping term 'nostra' as it already exists in the dataset.
# Skipping term 'nostre' as it already exists in the dataset.
# Skipping term 'nostri' as it already exists in the dataset.
# Skipping term 'nostro' as it already exists in the dataset.
# Skipping term 'notte' as it already exists in the dataset.
# Skipping term 'nuovo' as it already exists in the dataset.
# Skipping term 'o' as it already exists in the dataset.
# Skipping term 'occupato' as it already exists in the dataset.
# Skipping term 'ogni' as it already exists in the dataset.
# Skipping term 'oppure' as it already exists in the dataset.
# Skipping term 'ora' as it already exists in the dataset.
# Skipping term 'orario' as it already exists in the dataset.
# Skipping term 'ore' as it already exists in the dataset.
# Skipping term 'ostello' as it already exists in the dataset.
# Skipping term 'parla' as it already exists in the dataset.
# Skipping term 'parlo' as it already exists in the dataset.
# Skipping term 'passato' as it already exists in the dataset.
# Skipping term 'per' as it already exists in the dataset.
# Skipping term 'perché' as it already exists in the dataset.
# Skipping term 'permesso' as it already exists in the dataset.
# Skipping term 'persone' as it already exists in the dataset.
# Skipping term 'però' as it already exists in the dataset.
# Skipping term 'piace' as it already exists in the dataset.
# Skipping term 'piacere' as it already exists in the dataset.
# Skipping term 'piccola' as it already exists in the dataset.
# Skipping term 'piccolo' as it already exists in the dataset.
# Skipping term 'più' as it already exists in the dataset.
# Skipping term 'pochi' as it already exists in the dataset.
# Skipping term 'poco' as it already exists in the dataset.
# Skipping term 'polizia' as it already exists in the dataset.
# Skipping term 'posso' as it already exists in the dataset.
# Skipping term 'prenotazione' as it already exists in the dataset.
# Skipping term 'prima' as it already exists in the dataset.
# Skipping term 'primo' as it already exists in the dataset.
# Skipping term 'qualche' as it already exists in the dataset.
# Skipping term 'qualcosa' as it already exists in the dataset.
# Skipping term 'quale' as it already exists in the dataset.
# Skipping term 'quando' as it already exists in the dataset.
# Skipping term 'quante' as it already exists in the dataset.
# Skipping term 'quanti' as it already exists in the dataset.
# Skipping term 'quanto' as it already exists in the dataset.
# Skipping term 'quasi' as it already exists in the dataset.
# Skipping term 'quella' as it already exists in the dataset.
# Skipping term 'quelli' as it already exists in the dataset.
# Skipping term 'quello' as it already exists in the dataset.
# Skipping term 'questa' as it already exists in the dataset.
# Skipping term 'questi' as it already exists in the dataset.
# Skipping term 'questo' as it already exists in the dataset.
# Skipping term 'regali' as it already exists in the dataset.
# Skipping term 'regalo' as it already exists in the dataset.
# Skipping term 'ristorante' as it already exists in the dataset.
# Skipping term 'salumeria' as it already exists in the dataset.
# Skipping term 'se' as it already exists in the dataset.
# Skipping term 'sei' as it already exists in the dataset.
# Skipping term 'sempre' as it already exists in the dataset.
# Skipping term 'sera' as it already exists in the dataset.
# Skipping term 'si' as it already exists in the dataset.
# Skipping term 'signora' as it already exists in the dataset.
# Skipping term 'signore' as it already exists in the dataset.
# Skipping term 'sinistra' as it already exists in the dataset.
# Skipping term 'so' as it already exists in the dataset.
# Skipping term 'sono' as it already exists in the dataset.
# Skipping term 'stai' as it already exists in the dataset.
# Skipping term 'stati' as it already exists in the dataset.
# Skipping term 'stato' as it already exists in the dataset.
# Skipping term 'stesso' as it already exists in the dataset.
# Skipping term 'strada' as it already exists in the dataset.
# Skipping term 'su' as it already exists in the dataset.
# Skipping term 'sua' as it already exists in the dataset.
# Skipping term 'subito' as it already exists in the dataset.
# Skipping term 'sue' as it already exists in the dataset.
# Skipping term 'sul' as it already exists in the dataset.
# Skipping term 'suo' as it already exists in the dataset.
# Skipping term 'suoi' as it already exists in the dataset.
# Skipping term 'sì' as it already exists in the dataset.
# Skipping term 'tavolo' as it already exists in the dataset.
# Skipping term 'te' as it already exists in the dataset.
# Skipping term 'tempo' as it already exists in the dataset.
# Skipping term 'ti' as it already exists in the dataset.
# Skipping term 'tra' as it already exists in the dataset.
# Skipping term 'tre' as it already exists in the dataset.
# Skipping term 'treni' as it already exists in the dataset.
# Skipping term 'treno' as it already exists in the dataset.
# Skipping term 'troppo' as it already exists in the dataset.
# Skipping term 'tu' as it already exists in the dataset.
# Skipping term 'tua' as it already exists in the dataset.
# Skipping term 'tue' as it already exists in the dataset.
# Skipping term 'tuo' as it already exists in the dataset.
# Skipping term 'tuoi' as it already exists in the dataset.
# Skipping term 'tutto' as it already exists in the dataset.
# Skipping term 'un' as it already exists in the dataset.
# Skipping term 'un'amica' as it already exists in the dataset.
# Skipping term 'un'entrata' as it already exists in the dataset.
# Skipping term 'un'ora' as it already exists in the dataset.
# Skipping term 'una' as it already exists in the dataset.
# Skipping term 'uniti' as it already exists in the dataset.
# Skipping term 'uno' as it already exists in the dataset.
# Skipping term 'uomo' as it already exists in the dataset.
# Skipping term 'va' as it already exists in the dataset.
# Skipping term 'vado' as it already exists in the dataset.
# Skipping term 'vengo' as it already exists in the dataset.
# Skipping term 'vestiti' as it already exists in the dataset.
# Skipping term 'vicina' as it already exists in the dataset.
# Skipping term 'vicino' as it already exists in the dataset.
# Skipping term 'viene' as it already exists in the dataset.
# Skipping term 'vieni' as it already exists in the dataset.
# Skipping term 'villaggio' as it already exists in the dataset.
# Skipping term 'vini' as it already exists in the dataset.
# Skipping term 'voglio' as it already exists in the dataset.
# Skipping term 'voi' as it already exists in the dataset.
# Skipping term 'volete' as it already exists in the dataset.
# Skipping term 'volta' as it already exists in the dataset.
# Skipping term 'volte' as it already exists in the dataset.
# Skipping term 'vostra' as it already exists in the dataset.
# Skipping term 'vostre' as it already exists in the dataset.
# Skipping term 'vostri' as it already exists in the dataset.
# Skipping term 'vostro' as it already exists in the dataset.
# Skipping term 'vuoi' as it already exists in the dataset.
# Skipping term 'vuole' as it already exists in the dataset.
# Skipping term 'è' as it already exists in the dataset.
# 263

# %%
italian_words = sorted(new_list)

# %%
print(len(italian_words))
italian_words = [x for x in italian_words if 'mille' not in x]
print(len(italian_words))
# Out:
# 263
# 258

# %%
response_list = []
generated_files_list = []
cost_info_list = []
for term_it in tqdm(italian_words):

    all_df = get_all_terms_df()
    if term_it.lower() in all_df['term_italian'].str.lower().values:
        print(f"Skipping term '{term_it}' as it already exists in the dataset.")
        continue

    attempt_count = 0
    for attempt_count in range(3):
        try:
            print(f"Attempt {attempt_count + 1} for term: {term_it}")
            response, generated_files, cost_info = generate_csv(
                italian_term=term_it,
                model='gpt-5-mini',
                # model='gpt-5',
                reasoning_effort='medium',
            )
            response_list.append(response)
            generated_files_list.extend(generated_files)
            cost_info_list.append(cost_info)
            print(f"cost of this call: {cost_info['total_cost']}")
            break  # Exit the retry loop if successful
        except pd.errors.ParserError as e:
            print(f"ParserError on attempt {attempt_count + 1} for term '{term_it}': {e}")
            if attempt_count == 2:
                print(f"Failed to process term '{term_it}' after 3 attempts.")
        except Exception as e:
            print(f"Error on attempt {attempt_count + 1} for term '{term_it}': {e}")
            if attempt_count == 2:
                print(f"Failed to process term '{term_it}' after 3 attempts.")
# Out:
#   0%|          | 0/258 [00:00<?, ?it/s]
# Attempt 1 for term: costa

# %%
response_list

# %%
generated_files_list

# %%
cost_info_list
