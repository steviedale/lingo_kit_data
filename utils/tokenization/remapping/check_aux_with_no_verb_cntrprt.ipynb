# %%
import os
import pandas as pd

# %%
aux_list = [x.replace('.tsv', '') for x in os.listdir('dataframes/AUX')]
verb_list = [x.replace('.tsv', '') for x in os.listdir('dataframes/VERB')]
len(aux_list), len(verb_list)
# Out:
# (41, 3115)

# %%
set(aux_list).difference(set(verb_list))
# Out:
# {'avore',
#  'dosedere',
#  'dovmire',
#  'dwsiderare',
#  'essesere',
#  'essestare',
#  'essestere',
#  'essestire',
#  'il',
#  'stesso',
#  'stestere'}

# %%
# path = 'dataframes/AUX/avore.tsv'
# path = 'dataframes/AUX/dosedere.tsv'
# path = 'dataframes/AUX/dovmire.tsv'
# path = 'dataframes/AUX/dwsiderare.tsv'
# path = 'dataframes/AUX/essesere.tsv'
path = 'dataframes/AUX/essesere.tsv'
df = pd.read_csv(path, sep='\t')
df
# Out:
#       text pronunciation     lemma  pos translation_en  token_count  \
# 0  saresti  sah-REH-stee  essesere  AUX   you would be           28
#
#    token_pct  group_count  group_pct parts_lemma  ... deprel  \
# 0   0.000027           28   0.000027    essesere  ...    cop
#
#                                                feats  \
# 0  Mood=Cnd|Number=Sing|Person=1|Tense=Pres|VerbF...
#
#                              token_hash                            group_hash  \
# 0  da26d0fb-1120-54a0-b26c-80d7d3016b8f  878fab4d-def6-537a-babe-0551b761d170
#
#                                sentence_1_it  \
# 0  Saresti così gentile da aprirmi la porta?
#
#                                       sentence_1_en  \
# 0  Would you be so kind as to open the door for me?
#
#                                        sentence_2_it  \
# 0  La festa è stata divertente. Saresti dovuto ve...
#
#                                    sentence_2_en  \
# 0  The party was fun. You should have come, too.
#
# ...
